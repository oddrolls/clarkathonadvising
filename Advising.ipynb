# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.model_selection import train_test_split

# %%
file="CUF23CLASSLISTT.xlsx"
df_read=pd.read_excel(file)
dfclass=pd.DataFrame(df_read)

# %%
dfclass
# Out:
#       CRN  Course #   Sc                           Title    Attribute  Units  \
# 0   21754  CSCI 103    1     INTRO TO SOCIETAL COMPUTING  DI, FA, FYI      1
# 1   21755  CSCI 103    2     INTRO TO SOCIETAL COMPUTING       DI, FA      1
# 2   20017  CSCI 120    1       INTRODUCTION TO COMPUTING           SP      1
# 3   20348  CSCI 120    2       INTRODUCTION TO COMPUTING           SP      1
# 4   21861  CSCI 120  901         LAB: INTRO TO COMPUTING      FYI, SP      1
# 5   21862  CSCI 120  902         LAB: INTRO TO COMPUTING           SP      1
# 6   21242  CSCI 121    1                 DATA STRUCTURES           SP      1
# 7   21749  CSCI 122    1    INTRO TO DISCRETE STRUCTURES           FA      1
# 8   22412  CSCI 124    1       HONORS INTRO TO COMPUTING           SP      1
# 9   22413  CSCI 124  901  LAB: HONORS INTRO TO COMPUTING      FYI, SP      0
# 10  22414  CSCI 124  902  LAB: HONORS INTRO TO COMPUTING           SP      0
# ...

# %%
cs200lvl=["CSCI 201", "CSCI 210", "CSCI 215", "CSCI 220", "CSCI 244", "CSCI 245", "CSCI 250", "CSCI 262", "CSCI 265", "CSCI 268", "CSCI 270", "CSCI 280", "CSCI 282"]
cscore=["CSCI 140", "CSCI 160", "CSCI 170", "CSCI 180"]
ds200lvl= ["DSCI 215", "DSCI 216", "DSCI 225"]
ds105prqs=["GEOG110", "ECON160", "SOC202", "PSYC105", "PSCI107", "QBUS110", "MATH120", "MATH124"]
plsreqs=["GP", "LP", "SP", "AP", "VP", "HP", "DI", "POP", "FA", "VE", "DI"]

# %%
major=input("What is your intended major?\n")
year=input("What is your year?\n")
pls=input("What PLS requirements do you have already?\n")
# Out:
# What is your intended major?
# DSCI
# What is your year?
# 1
# What PLS requirements do you have already?
# GP

# %%
intro
# Out:
#      CRN  Course #   Sc                      Title Attribute  Units  CAP  Enr  \
# 2  20017  CSCI 120    1  INTRODUCTION TO COMPUTING        SP      1   50   49
# 3  20348  CSCI 120    2  INTRODUCTION TO COMPUTING        SP      1   50   49
# 4  21861  CSCI 120  901    LAB: INTRO TO COMPUTING   FYI, SP      1   18   18
# 5  21862  CSCI 120  902    LAB: INTRO TO COMPUTING        SP      1   32   31
#
#        Instructor   Days                                     Times  \
# 2  Catalin Veghes     MF                       09:00 AM - 10:15 AM
# 3  Catalin Veghes  MR, F                       01:25 PM - 02:40 PM
# 4  Catalin Veghes   W, R  09:00 AM - 10:15 AM, 12:00 PM - 12:50 PM
# 5  Catalin Veghes      W                       09:00 AM - 10:15 AM
#
#              Room  PRQ                                           Comments  \
# 2         MACD117  NaN  REG FOR LAB 902; 37 SEATS RESERVED FOR INCOMIN...
# 3         MACD117  NaN                                    LAPTOP REQUIRED
# ...

# %%
row=intro.iloc[3]

# %%
row
# Out:
# CRN                                                      21862
# Course #                                              CSCI 120
# Sc                                                         902
# Title                                  LAB: INTRO TO COMPUTING
# Attribute                                                   SP
# Units                                                        1
# CAP                                                         32
# Enr                                                         31
# Instructor                                      Catalin Veghes
# Days                                                         W
# Times                                      09:00 AM - 10:15 AM
# Room                                                   MACD117
# PRQ                                                        NaN
# Comments      LAPTOP REQUIRED; 10 SEATS REQUIRED FOR 1ST YEARS
# Perm Only                                                    N
# Name: 5, dtype: object

# %%
if year==1:
    intro=pd.DataFrame(data=(dfclass.loc[(dfclass["Course #"]=="CSCI 120")]))
    col=[]
    for i in range(4):
        row=intro.iloc[i]
        enr=row['Enr']
        cap=row['CAP']
        if enr != cap:
            col.append(i)
        recs=pd.DataFrame(data=intro.iloc[col])
    recs
elif major == "DATA SCIENCE" or "DSCI":
    
elif major == "COMPUTER SCIENCE" or "CSCI":
# Out:
#      CRN  Course #   Sc                      Title Attribute  Units  CAP  Enr  \
# 2  20017  CSCI 120    1  INTRODUCTION TO COMPUTING        SP      1   50   49
# 3  20348  CSCI 120    2  INTRODUCTION TO COMPUTING        SP      1   50   49
# 5  21862  CSCI 120  902    LAB: INTRO TO COMPUTING        SP      1   32   31
#
#        Instructor   Days                Times     Room  PRQ  \
# 2  Catalin Veghes     MF  09:00 AM - 10:15 AM  MACD117  NaN
# 3  Catalin Veghes  MR, F  01:25 PM - 02:40 PM  MACD117  NaN
# 5  Catalin Veghes      W  09:00 AM - 10:15 AM  MACD117  NaN
#
#                                             Comments Perm Only
# 2  REG FOR LAB 902; 37 SEATS RESERVED FOR INCOMIN...         N
# 3                                    LAPTOP REQUIRED         N
# 5   LAPTOP REQUIRED; 10 SEATS REQUIRED FOR 1ST YEARS         N
